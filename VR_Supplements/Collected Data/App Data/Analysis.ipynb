# %%
PUMP_LEVELS = [0, 200, 466, 733, 999]
VALVE_LEVELS = [0, 10, 40, 70, 100]
log_dir = "u01"

# PUMP_LEVELS = [0, 200, 400, 700, 999]
# VALVE_LEVELS = [0, 10, 20, 50, 100]
# log_dir = "u02"

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def map_to_index(value, levels):
    """Map a numeric value to its closest index in a known level list."""
    return min(range(len(levels)), key=lambda i: abs(value - levels[i]))

def load_delivered_trials(trials_json_path):
    with open(trials_json_path, 'r') as f:
        trials = json.load(f)
    # Build a dict: trial_number → (vibration_delivered, pressure_delivered)
    return {
        trial["trial_number"]: (trial["vibration_delivered"], trial["pressure_delivered"])
        for trial in trials
    }

def load_selected_response(log_file_path):
    with open(log_file_path, 'r') as f:
        data = json.load(f)
    if not data:
        return None
    last_entry = data[-1]
    pump_val = last_entry.get("pump", 0)
    valve_val = last_entry.get("valve", 0)
    pressure_selected = map_to_index(pump_val, PUMP_LEVELS)
    vibration_selected = map_to_index(valve_val, VALVE_LEVELS)
    return pressure_selected, vibration_selected

def parse_all_trials(log_dir, trials_json_path):
    delivered = load_delivered_trials(trials_json_path)
    results = []

    for filename in sorted(os.listdir(log_dir)):
        if filename.endswith("_log.json") and "training" not in filename:
            try:
                trial_num = int(filename.split("_trial")[1].split("_")[0])
                log_path = os.path.join(log_dir, filename)
                selected = load_selected_response(log_path)
                if selected:
                    pressure_selected, vibration_selected = selected
                    vibration_delivered, pressure_delivered = delivered[trial_num]
                    results.append({
                        "trial": trial_num,
                        "vibration_delivered": vibration_delivered,
                        "pressure_delivered": pressure_delivered,
                        "vibration_selected": vibration_selected,
                        "pressure_selected": pressure_selected
                    })
            except Exception as e:
                print(f"⚠️ Skipping {filename}: {e}")
    return results

# === Run ===
trials_json_path = f"App Trials/generated_trials/{log_dir}_trials.json"

parsed_results = parse_all_trials(log_dir, trials_json_path)

# Optional: Print or save
for entry in parsed_results:
    print(entry)
# Out:
# {'trial': 10, 'vibration_delivered': 0, 'pressure_delivered': 3, 'vibration_selected': 0, 'pressure_selected': 3}
# {'trial': 11, 'vibration_delivered': 2, 'pressure_delivered': 2, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 12, 'vibration_delivered': 1, 'pressure_delivered': 1, 'vibration_selected': 1, 'pressure_selected': 1}
# {'trial': 13, 'vibration_delivered': 2, 'pressure_delivered': 1, 'vibration_selected': 2, 'pressure_selected': 1}
# {'trial': 14, 'vibration_delivered': 1, 'pressure_delivered': 2, 'vibration_selected': 1, 'pressure_selected': 2}
# {'trial': 15, 'vibration_delivered': 3, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 2}
# {'trial': 16, 'vibration_delivered': 1, 'pressure_delivered': 3, 'vibration_selected': 1, 'pressure_selected': 2}
# {'trial': 17, 'vibration_delivered': 4, 'pressure_delivered': 3, 'vibration_selected': 3, 'pressure_selected': 1}
# {'trial': 18, 'vibration_delivered': 0, 'pressure_delivered': 4, 'vibration_selected': 0, 'pressure_selected': 3}
# {'trial': 19, 'vibration_delivered': 4, 'pressure_delivered': 1, 'vibration_selected': 3, 'pressure_selected': 1}
# {'trial': 1, 'vibration_delivered': 3, 'pressure_delivered': 2, 'vibration_selected': 2, 'pressure_selected': 1}
# {'trial': 20, 'vibration_delivered': 0, 'pressure_delivered': 2, 'vibration_selected': 0, 'pressure_selected': 2}
# {'trial': 21, 'vibration_delivered': 3, 'pressure_delivered': 2, 'vibration_selected': 2, 'pressure_selected': 2}
# {'trial': 22, 'vibration_delivered': 4, 'pressure_delivered': 1, 'vibration_selected': 0, 'pressure_selected': 1}
# {'trial': 23, 'vibration_delivered': 4, 'pressure_delivered': 4, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 24, 'vibration_delivered': 1, 'pressure_delivered': 2, 'vibration_selected': 1, 'pressure_selected': 1}
# {'trial': 25, 'vibration_delivered': 0, 'pressure_delivered': 4, 'vibration_selected': 0, 'pressure_selected': 3}
# {'trial': 26, 'vibration_delivered': 1, 'pressure_delivered': 1, 'vibration_selected': 1, 'pressure_selected': 1}
# {'trial': 27, 'vibration_delivered': 3, 'pressure_delivered': 1, 'vibration_selected': 1, 'pressure_selected': 2}
# {'trial': 28, 'vibration_delivered': 4, 'pressure_delivered': 3, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 29, 'vibration_delivered': 2, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 2}
# {'trial': 2, 'vibration_delivered': 1, 'pressure_delivered': 4, 'vibration_selected': 1, 'pressure_selected': 3}
# {'trial': 30, 'vibration_delivered': 2, 'pressure_delivered': 3, 'vibration_selected': 3, 'pressure_selected': 3}
# {'trial': 31, 'vibration_delivered': 3, 'pressure_delivered': 3, 'vibration_selected': 4, 'pressure_selected': 2}
# {'trial': 32, 'vibration_delivered': 3, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 33, 'vibration_delivered': 1, 'pressure_delivered': 4, 'vibration_selected': 1, 'pressure_selected': 3}
# {'trial': 34, 'vibration_delivered': 2, 'pressure_delivered': 1, 'vibration_selected': 2, 'pressure_selected': 1}
# {'trial': 35, 'vibration_delivered': 0, 'pressure_delivered': 2, 'vibration_selected': 0, 'pressure_selected': 1}
# {'trial': 36, 'vibration_delivered': 4, 'pressure_delivered': 2, 'vibration_selected': 2, 'pressure_selected': 2}
# {'trial': 37, 'vibration_delivered': 0, 'pressure_delivered': 3, 'vibration_selected': 0, 'pressure_selected': 3}
# {'trial': 38, 'vibration_delivered': 1, 'pressure_delivered': 3, 'vibration_selected': 1, 'pressure_selected': 3}
# {'trial': 39, 'vibration_delivered': 0, 'pressure_delivered': 1, 'vibration_selected': 0, 'pressure_selected': 1}
# {'trial': 3, 'vibration_delivered': 0, 'pressure_delivered': 1, 'vibration_selected': 0, 'pressure_selected': 1}
# {'trial': 40, 'vibration_delivered': 2, 'pressure_delivered': 2, 'vibration_selected': 3, 'pressure_selected': 1}
# {'trial': 41, 'vibration_delivered': 1, 'pressure_delivered': 1, 'vibration_selected': 1, 'pressure_selected': 1}
# {'trial': 42, 'vibration_delivered': 4, 'pressure_delivered': 2, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 43, 'vibration_delivered': 0, 'pressure_delivered': 3, 'vibration_selected': 0, 'pressure_selected': 3}
# {'trial': 44, 'vibration_delivered': 0, 'pressure_delivered': 1, 'vibration_selected': 0, 'pressure_selected': 1}
# {'trial': 45, 'vibration_delivered': 3, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 46, 'vibration_delivered': 4, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 2}
# {'trial': 47, 'vibration_delivered': 2, 'pressure_delivered': 3, 'vibration_selected': 3, 'pressure_selected': 3}
# {'trial': 48, 'vibration_delivered': 3, 'pressure_delivered': 3, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 49, 'vibration_delivered': 1, 'pressure_delivered': 3, 'vibration_selected': 1, 'pressure_selected': 3}
# {'trial': 4, 'vibration_delivered': 3, 'pressure_delivered': 1, 'vibration_selected': 3, 'pressure_selected': 1}
# {'trial': 50, 'vibration_delivered': 0, 'pressure_delivered': 4, 'vibration_selected': 0, 'pressure_selected': 4}
# {'trial': 51, 'vibration_delivered': 0, 'pressure_delivered': 2, 'vibration_selected': 0, 'pressure_selected': 2}
# {'trial': 52, 'vibration_delivered': 2, 'pressure_delivered': 4, 'vibration_selected': 0, 'pressure_selected': 2}
# {'trial': 53, 'vibration_delivered': 2, 'pressure_delivered': 2, 'vibration_selected': 2, 'pressure_selected': 3}
# {'trial': 54, 'vibration_delivered': 2, 'pressure_delivered': 1, 'vibration_selected': 2, 'pressure_selected': 1}
# {'trial': 55, 'vibration_delivered': 3, 'pressure_delivered': 1, 'vibration_selected': 3, 'pressure_selected': 1}
# {'trial': 56, 'vibration_delivered': 1, 'pressure_delivered': 4, 'vibration_selected': 1, 'pressure_selected': 3}
# {'trial': 57, 'vibration_delivered': 3, 'pressure_delivered': 2, 'vibration_selected': 2, 'pressure_selected': 2}
# {'trial': 58, 'vibration_delivered': 1, 'pressure_delivered': 2, 'vibration_selected': 1, 'pressure_selected': 2}
# {'trial': 59, 'vibration_delivered': 4, 'pressure_delivered': 1, 'vibration_selected': 2, 'pressure_selected': 2}
# {'trial': 5, 'vibration_delivered': 3, 'pressure_delivered': 3, 'vibration_selected': 4, 'pressure_selected': 2}
# {'trial': 60, 'vibration_delivered': 4, 'pressure_delivered': 3, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 61, 'vibration_delivered': 1, 'pressure_delivered': 1, 'vibration_selected': 1, 'pressure_selected': 1}
# {'trial': 62, 'vibration_delivered': 2, 'pressure_delivered': 2, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 63, 'vibration_delivered': 2, 'pressure_delivered': 3, 'vibration_selected': 3, 'pressure_selected': 3}
# {'trial': 64, 'vibration_delivered': 4, 'pressure_delivered': 1, 'vibration_selected': 2, 'pressure_selected': 1}
# {'trial': 65, 'vibration_delivered': 2, 'pressure_delivered': 4, 'vibration_selected': 3, 'pressure_selected': 3}
# {'trial': 66, 'vibration_delivered': 3, 'pressure_delivered': 1, 'vibration_selected': 4, 'pressure_selected': 1}
# {'trial': 67, 'vibration_delivered': 0, 'pressure_delivered': 2, 'vibration_selected': 0, 'pressure_selected': 2}
# {'trial': 68, 'vibration_delivered': 4, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 69, 'vibration_delivered': 0, 'pressure_delivered': 3, 'vibration_selected': 0, 'pressure_selected': 3}
# {'trial': 6, 'vibration_delivered': 4, 'pressure_delivered': 2, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 70, 'vibration_delivered': 4, 'pressure_delivered': 3, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 71, 'vibration_delivered': 1, 'pressure_delivered': 3, 'vibration_selected': 1, 'pressure_selected': 2}
# {'trial': 72, 'vibration_delivered': 1, 'pressure_delivered': 2, 'vibration_selected': 1, 'pressure_selected': 2}
# {'trial': 73, 'vibration_delivered': 1, 'pressure_delivered': 4, 'vibration_selected': 1, 'pressure_selected': 3}
# {'trial': 74, 'vibration_delivered': 2, 'pressure_delivered': 1, 'vibration_selected': 2, 'pressure_selected': 3}
# {'trial': 75, 'vibration_delivered': 3, 'pressure_delivered': 2, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 76, 'vibration_delivered': 4, 'pressure_delivered': 2, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 77, 'vibration_delivered': 0, 'pressure_delivered': 4, 'vibration_selected': 0, 'pressure_selected': 4}
# {'trial': 78, 'vibration_delivered': 3, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 3}
# {'trial': 79, 'vibration_delivered': 3, 'pressure_delivered': 3, 'vibration_selected': 4, 'pressure_selected': 4}
# {'trial': 7, 'vibration_delivered': 2, 'pressure_delivered': 3, 'vibration_selected': 4, 'pressure_selected': 2}
# {'trial': 80, 'vibration_delivered': 0, 'pressure_delivered': 1, 'vibration_selected': 0, 'pressure_selected': 1}
# {'trial': 8, 'vibration_delivered': 4, 'pressure_delivered': 4, 'vibration_selected': 3, 'pressure_selected': 2}
# {'trial': 9, 'vibration_delivered': 2, 'pressure_delivered': 4, 'vibration_selected': 4, 'pressure_selected': 3}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def build_confusion_matrix(results, normalize=False):
    """
    Build a 2D confusion matrix with multi-index rows and columns:
    (vibration_delivered, pressure_delivered) → (vibration_selected, pressure_selected)
    """
    # Build flat count matrix
    matrix = {}

    for r in results:
        key = (r["vibration_delivered"], r["pressure_delivered"])
        val = (r["vibration_selected"], r["pressure_selected"])
        matrix[(key, val)] = matrix.get((key, val), 0) + 1

    # Convert to full DataFrame
    all_labels = [(v, p) for v in range(5) for p in range(1, 5)]
    df = pd.DataFrame(
        0, index=pd.MultiIndex.from_tuples(all_labels, names=["V_Del", "P_Del"]),
        columns=pd.MultiIndex.from_tuples(all_labels, names=["V_Sel", "P_Sel"])
    )

    for (delivered, selected), count in matrix.items():
        df.loc[delivered, selected] = count

    if normalize:
        df = df.div(df.sum(axis=1), axis=0).fillna(0)

    return df

def plot_confusion_matrix(conf_matrix, title="Confusion Matrix", cmap="Blues"):
    """Display a heatmap from a 2D MultiIndex confusion matrix"""
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt=".0f" if conf_matrix.values.max() > 1 else ".2f",
                cmap=cmap, cbar=True)
    plt.title(title)
    plt.xlabel("Perceived (Vibration, Pressure)")
    plt.ylabel("Delivered (Vibration, Pressure)")
    plt.tight_layout()
    plt.show()

# %%
# Assuming `parsed_results` from earlier
conf_mat = build_confusion_matrix(parsed_results, normalize=False)  # or True
plot_confusion_matrix(conf_mat, title="Perceptual Confusion Matrix")

# %%
def build_vibration_confusion(results, normalize=False):
    matrix = pd.DataFrame(0, index=range(5), columns=range(5))  # 0–4
    for r in results:
        v_d = r["vibration_delivered"]
        v_s = r["vibration_selected"]
        matrix.loc[v_d, v_s] += 1
    if normalize:
        matrix = matrix.div(matrix.sum(axis=1), axis=0).fillna(0)
    return matrix

def build_pressure_confusion(results, normalize=False):
    matrix = pd.DataFrame(0, index=range(1, 5), columns=range(1, 5))  # 1–4
    for r in results:
        p_d = r["pressure_delivered"]
        p_s = r["pressure_selected"]
        matrix.loc[p_d, p_s] += 1
    if normalize:
        matrix = matrix.div(matrix.sum(axis=1), axis=0).fillna(0)
    return matrix

def plot_confusion(matrix, title, xlabel, ylabel, cmap="Blues"):
    plt.figure(figsize=(6, 5))
    sns.heatmap(matrix, annot=True, fmt=".0f" if matrix.values.max() > 1 else ".2f", cmap=cmap)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.tight_layout()
    plt.show()

# %%
vib_matrix = build_vibration_confusion(parsed_results, normalize=False)
pres_matrix = build_pressure_confusion(parsed_results, normalize=False)

plot_confusion(vib_matrix, "Vibration Confusion Matrix", "Selected", "Delivered")
plot_confusion(pres_matrix, "Pressure Confusion Matrix", "Selected", "Delivered")
